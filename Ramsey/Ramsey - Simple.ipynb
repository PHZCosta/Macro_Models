# %%
# This is a simpler version of the jupyter notebook Ramsey.ipynb, instead of defining the class in itself,
# it imports the class from the file Ramsey.py

# Importing the class from the file Ramsey.py
from Ramsey_model import Ramsey

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# Defining default values for graph plotting
plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams.update({'font.size': 15})

# %%
R1 = Ramsey()
R2 = Ramsey(theta=2)

# %%
R1.graph_saddle_path()
R2.graph_saddle_path()
